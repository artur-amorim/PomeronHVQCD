# %%
# Import numpy, pandas and matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
wf_data = pd.read_csv("wf_0.txt",sep = '\t')
plt.plot(wf_data["z"],wf_data["psi"])
plt.ylabel(r'$\psi_0$')
plt.xlabel("z")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-01179bfa0188> in <module>
# ----> 1 wf_data = pd.read_csv("wf_0.txt",sep = '\t')
#       2 plt.plot(wf_data["z"],wf_data["psi"])
#       3 plt.ylabel(r'$\psi_0$')
#       4 plt.xlabel("z")
#       5 plt.show()
#
# ...

# %%
wf_data = pd.read_csv("wf_1.txt",sep = '\t')
plt.plot(wf_data["z"],wf_data["psi"])
plt.ylabel(r'$\psi_1$')
plt.xlabel("z")
plt.show()

# %%
wf_data = pd.read_csv("wf_2.txt",sep = '\t')
plt.plot(wf_data["z"],wf_data["psi"])
plt.ylabel(r'$\psi_2$')
plt.xlabel("z")
plt.show()

# %%
wf_data = pd.read_csv("wf_3.txt",sep = '\t')
plt.plot(wf_data["z"],wf_data["psi"])
plt.ylabel(r'$\psi_3$')
plt.xlabel("z")
plt.show()

# %%
potential_data_0 = pd.read_csv("potential_0.txt",sep = '\t')
potential_data_1 = pd.read_csv("potential_1.txt",sep = '\t')
potential_data_2 = pd.read_csv("potential_2.txt",sep = '\t')
potential_data_3 = pd.read_csv("potential_3.txt",sep = '\t')
plt.plot(potential_data_0["z"],potential_data_0["potential"])
plt.ylabel("V")
plt.xlabel("z")
plt.ylim(-3000,1000)
plt.xlim(-0.2,3)
plt.show()
plt.plot(potential_data_1["z"],potential_data_1["potential"])
plt.ylabel("V")
plt.xlabel("z")
plt.ylim(-100,1000)
plt.xlim(-0.2,3)
plt.show()
plt.plot(potential_data_2["z"],potential_data_2["potential"])
plt.ylabel("V")
plt.xlabel("z")
plt.ylim(-1000,1000)
plt.xlim(-0.2,3)
plt.show()
plt.plot(potential_data_3["z"],potential_data_3["potential"])
plt.ylabel("V")
plt.xlabel("z")
plt.ylim(-1000,1000)
plt.xlim(-0.2,3)
plt.show()

# %%
# Plot U2 potential data
u2_data = pd.read_csv("gluon_pot_J_2_vs_glueball_potential.txt",sep='\t')
plt.plot(u2_data["z"],u2_data["glue"], label = "gluon potential J = 2")
plt.plot(u2_data["z"],u2_data["glueball"], label = "2^{++} glueball potential")
plt.ylabel("V")
plt.xlabel("z")
#plt.ylim(-50,2000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot aF data
aF_data = pd.read_csv("aF_vs_z.txt",sep='\t')
plt.plot(aF_data["z"],aF_data["aF"], label = "aF")
plt.ylabel("aF")
plt.xlabel("z")
#plt.ylim(-100,10)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot bF data
bF_data = pd.read_csv("bF_vs_z.txt",sep='\t')
plt.plot(bF_data["z"],bF_data["bF"], label = "bF")
plt.ylabel("bF")
plt.xlabel("z")
#plt.ylim(-100,1000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot cF data
cF_data = pd.read_csv("cF_vs_z.txt",sep='\t')
plt.plot(cF_data["z"],cF_data["cF"], label = "cF")
plt.ylabel("cF")
plt.xlabel("z")
#plt.ylim(-200,200)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot dF data
dF_data = pd.read_csv("dF_vs_z.txt",sep='\t')
plt.plot(dF_data["z"],dF_data["dF"], label = "dF")
plt.ylabel("dF")
plt.xlabel("z")
#plt.ylim(-200,200)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot eF data
eF_data = pd.read_csv("eF_vs_z.txt",sep='\t')
plt.plot(eF_data["z"],eF_data["eF"], label = "eF")
plt.ylabel("eF")
plt.xlabel("z")
#plt.ylim(0,1000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot e2A data
e2A_data = pd.read_csv("e2A_vs_z.txt",sep='\t')
plt.plot(e2A_data["z"],e2A_data["e2A"], label = "e2A")
plt.ylabel("e2A")
plt.xlabel("z")
plt.ylim(-100,1000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot e2Astring data
e2Astring_data = pd.read_csv("e2Astring_vs_z.txt",sep='\t')
plt.plot(e2Astring_data["z"],e2Astring_data["e2Astring"], label = "e2Astring")
plt.ylabel("e2Astring")
plt.xlabel("z")
plt.ylim(-100,1000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()

# %%
# Plot l1_2 data
l1_2_data = pd.read_csv("l1_2_vs_z.txt",sep='\t')
plt.plot(l1_2_data["z"],l1_2_data["l1_2"], label = "l1_2")
plt.ylabel("l1_2")
plt.xlabel("z")
plt.ylim(-100,1000)
plt.xlim(-0.2,3.5)
plt.legend()
plt.show()
