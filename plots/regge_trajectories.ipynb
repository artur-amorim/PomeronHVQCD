# %%
#import numpy, pandas and pyplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
regge_trajectories_data = pd.read_csv('regge_trajectories.txt', sep = '\t')

# %%
plt.plot(regge_trajectories_data["t"], regge_trajectories_data["gluon_j0"], label = 'gluon0')
plt.plot(regge_trajectories_data["t"], regge_trajectories_data["gluon_j1"], label = 'gluon1')
#plt.plot(regge_trajectories_data["t"], regge_trajectories_data["gluon_j2"], label = 'gluon2')
#plt.plot(regge_trajectories_data["t"], regge_trajectories_data["gluon_j3"], label = 'gluon3')
plt.plot(regge_trajectories_data["t"], regge_trajectories_data["meson_j0"], label = 'meson0')
#plt.plot(regge_trajectories_data["t"], regge_trajectories_data["meson_j1"], label = 'meson1')
plt.xlim(-1,2)
plt.ylim(0, 3.7)
plt.legend()
plt.show()
