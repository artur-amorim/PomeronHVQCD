# %%
# import pandas, numpy and pyplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("U1NNMode_Q2_10.000000.txt", sep = '\t', skiprows = 1)
plt.plot(data["u"], data["fQ"])
plt.xlabel("u")
plt.ylabel("fQ")
plt.xlim(-0.1,10)
plt.show()
plt.plot(data["u"], data["dfQ/du"])
plt.xlabel("u")
plt.ylabel("dfQ/du")
plt.xlim(-0.1,10)
plt.show()
plt.plot(data["u"], data["fQ^2 + (dfQ/du)^2/Q2"])
plt.xlabel("u")
plt.ylabel("factor")
plt.xlim(-0.1,10)
plt.show()
